# %%
# %%script node
# var livelySolver = require('../../src/lively');
# console.log("hello, world!");
# Out:
# node:internal/modules/cjs/loader:998
#   throw err;
#   ^
#
# Error: Cannot find module '../../src/lively'
# Require stack:
# - /Users/hunterzhang/Desktop/lively/examples/js_examples/[stdin]
#     at Module._resolveFilename (node:internal/modules/cjs/loader:995:15)
#     at Module._load (node:internal/modules/cjs/loader:841:27)
#     at Module.require (node:internal/modules/cjs/loader:1061:19)
#     at require (node:internal/modules/cjs/helpers:103:18)
#     at [stdin]:1:20
#     at Script.runInThisContext (node:vm:129:12)
#     at Object.runInThisContext (node:vm:313:38)
#     at node:internal/process/execution:79:19
#     at [stdin]-wrapper:6:22
#     at evalScript (node:internal/process/execution:78:60) {
#   code: 'MODULE_NOT_FOUND',
#   requireStack: [ '/Users/hunterzhang/Desktop/lively/examples/js_examples/[stdin]' ]
# }
#
# Node.js v18.12.1
# ---------------------------------------------------------------------------
# ...
